# %% [markdown]
# # Sales Data Analysis Dashboard - Professional Notebook\n**Codomax Data Science Internship - Day 12 Project Improvement**\nThis notebook contains well-formatted code, clear comments, data cleaning steps, and professional data visualizations.

# %%
import pandas as pd\nimport numpy as np\nimport matplotlib.pyplot as plt\n\n# Load cleaned dataset\ndf = pd.read_csv('../Day_10_Export_Data/final_cleaned_sales_data.csv')\ndf.head()

# %% [markdown]
# ### Key Business Metrics Summary

# %%
print('Total Revenue:', df['Total_Amount'].sum())\nprint('Average Order Value:', df['Total_Amount'].mean())
